# %%
# !pip install gensim nltk
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize
# Out:
# Requirement already satisfied: gensim in C:\Users\DIVYA\AppData\Local\Programs\Python\Python312\Lib\site-packages (4.4.0)
# Requirement already satisfied: nltk in C:\Users\DIVYA\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in C:\Users\DIVYA\AppData\Local\Programs\Python\Python312\Lib\site-packages (from gensim) (2.1.3)
# Requirement already satisfied: scipy>=1.7.0 in C:\Users\DIVYA\AppData\Local\Programs\Python\Python312\Lib\site-packages (from gensim) (1.18.0)
# Requirement already satisfied: smart_open>=1.8.1 in C:\Users\DIVYA\AppData\Local\Programs\Python\Python312\Lib\site-packages (from gensim) (8.0.1)
# Requirement already satisfied: defusedxml in C:\Users\DIVYA\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk) (0.7.1)
# Requirement already satisfied: click in C:\Users\DIVYA\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk) (8.4.2)
# Requirement already satisfied: joblib in C:\Users\DIVYA\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\DIVYA\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk) (2026.7.19)
# Requirement already satisfied: tqdm in C:\Users\DIVYA\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk) (4.69.1)
# Requirement already satisfied: wrapt in C:\Users\DIVYA\AppData\Local\Programs\Python\Python312\Lib\site-packages (from smart_open>=1.8.1->gensim) (2.2.2)
# Requirement already satisfied: colorama in C:\Users\DIVYA\AppData\Local\Programs\Python\Python312\Lib\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 26.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# C:\Users\DIVYA\AppData\Local\Programs\Python\Python312\Lib\ssl.py:524: UserWarning: Bad certificate in Windows certificate store: not enough data: cadata does not contain a certificate (_ssl.c:4014)
#   warnings.warn(f"Bad certificate in Windows certificate store: {exc!s}")
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DIVYA\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\DIVYA\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
data = [
    "This is the first document",
    "This is the second document",
    "This is the third document",
    "This is the fourth document"
]

# %%
tagged_data = [
    TaggedDocument(
        words=word_tokenize(doc.lower()),
        tags=[str(i)]
    )
    for i, doc in enumerate(data)
]

# %%
model = Doc2Vec( 
    vector_size=20, 
    min_count=2, 
    epochs=50 
)

# %%
model.build_vocab(tagged_data) 
model.train( 
    tagged_data, 
    total_examples=model.corpus_count, 
    epochs=model.epochs 
)

# %%
document_vectors = [ 
    model.infer_vector(word_tokenize(doc.lower())) 
    for doc in data 
]

# %%
for i, doc in enumerate(data): 
    print("Document", i + 1, ":", doc) 
    print("Vector:", document_vectors[i]) 
    print()
# Out:
# Document 1 : This is the first document
# Vector: [ 0.0155225   0.00723378 -0.00717613  0.01758851  0.02527769 -0.01556652
#   0.01364933 -0.01091398  0.02411973 -0.02316908 -0.00507075  0.01688625
#   0.00803183  0.00673243 -0.01965277 -0.00078458  0.00307809  0.02174417
#  -0.000784   -0.02149724]
#
# Document 2 : This is the second document
# Vector: [-0.02511051  0.00095243  0.0103526  -0.00781049 -0.01295765 -0.01571011
#  -0.01342275 -0.01080281 -0.01054133 -0.00233691  0.0129858   0.00031512
#  -0.02118194  0.02043235 -0.00811312 -0.02371505 -0.00889426  0.00645054
#  -0.00024424  0.02045202]
#
# Document 3 : This is the third document
# Vector: [ 0.00152975 -0.00061314 -0.00263801 -0.00677395  0.01273897  0.00735722
#   0.01740297  0.02157821  0.00449892  0.00211333 -0.01402811  0.01430432
#   0.00997612  0.02106593  0.0164267  -0.01463738  0.00074295 -0.0016845
#  -0.01244639 -0.01224713]
#
# Document 4 : This is the fourth document
# Vector: [ 0.0004318   0.0085126  -0.01324526  0.00974879  0.0169569  -0.0050338
#  -0.02233267 -0.00908425  0.02503775 -0.01261912  0.00928981 -0.0202408
#  -0.00449182 -0.00025624 -0.01221869 -0.01836488  0.00905292 -0.00463101
#  -0.00360555 -0.01309728]
